# %% [markdown]
# <a href="https://colab.research.google.com/github/djmayo04/AI_Mini-Project2/blob/main/notebooks/AI_MP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain-groq groq
# Out:
# ...
#   Using cached groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# ...

# %%
import os

REPO_URL = "https://github.com/djmayo04/AI_Mini-Project2.git"
REPO_DIR = "AI_Mini-Project2"

# %cd /content

if not os.path.exists(REPO_DIR):
    # !git clone "https://github.com/djmayo04/AI_Mini-Project2.git"
else:
    # %cd {REPO_DIR}
    # !git pull
    # %cd /content

# %cd {REPO_DIR}
# !ls
# Out:
# /content
# /content/AI_Mini-Project2
# Already up to date.
# /content
# /content/AI_Mini-Project2
# agent.py  llm_helper.py  notebooks    README.md		   tools.py
# data	  memory.py	 __pycache__  search_documents.py

# %%
import os
from google.colab import userdata
os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')
print(os.environ.get("GROQ_API_KEY") is not None)
# Out:
# True

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip install -U langchain langchain-community

# %%
# load the data
from langchain_community.document_loaders import TextLoader
loaderA1 = TextLoader("/content/AI_Mini-Project2/data/Assignment1.txt")

# %%
# !pip install -U langchain-text-splitters

# %%
from llm_helper import chunk_split
assignment = loaderA1.load()
chunksA1 = chunk_split(assignment[0].page_content)

# %%
# !pip install chromadb

# %%
from langchain_community.vectorstores import Chroma

vectorstore = Chroma(persist_directory="./chroma_db")
vectorstore.add_texts(chunksA1)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 42.9MiB/s]
# ['d9c34b01-d37b-42ac-abb6-d0221ba516dc',
#  'ffaadbc4-43d5-4f13-af0b-61737e2224e5',
#  'adedbc95-8e5e-4362-841c-1f617bc633e2']

# %%
data = vectorstore.get()
print(data)
# Out:
# {'ids': ['d9c34b01-d37b-42ac-abb6-d0221ba516dc', 'ffaadbc4-43d5-4f13-af0b-61737e2224e5', 'adedbc95-8e5e-4362-841c-1f617bc633e2'], 'embeddings': None, 'documents': ['Assignment 1: Rational Agent Design\n\nObjective:\nDesign and analyze a rational agent using the PEAS framework.', 'Instructions:\n1. Define the environment in which your agent operates.\n2. Clearly describe:\n   - Performance Measure\n   - Environment\n   - Actuators\n   - Sensors\n3. Provide a diagram of the agent architecture.\n4. Explain whether the environment is:\n   - Fully or partially observable\n   - Deterministic or stochastic\n   - Episodic or sequential\n   - Static or dynamic\n   - Discrete or continuous\n\nDeliverables:\n- 2–3 page PDF report\n- Architecture diagram\n- Formal PEAS table', 'Due Date:\nFebruary 25 at 11:59 PM\n\nGrading Criteria:\n- Clarity of PEAS definition\n- Correct classification of the environment\n- Quality of reasoning\n- Diagram clarity'], 'uris': None, 'included': ['metadatas', 'doc
# ...

# %%
from llm_helper import get_completion
from agent import run_agent

print(get_completion("Say hello in one sentence."))
print(run_agent("What does the syllabus say about deadlines?"))
# Out:
# Hello!
# I’m not seeing the specific wording from the syllabus about deadlines in the information I have. If you can share the relevant excerpt or provide a bit more detail about the course (e.g., the course name/number or a copy of the syllabus), I’ll be happy to help interpret what it says about deadlines.

# %%
# !ls notebooks
# Out:
# 04_groq.ipynb  AI_MP2.ipynb
